# %%
# %matplotlib notebook

import geopandas as gpd
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import geoplot


sql = "select * from gadm36_ind_1"

con = psycopg2.connect(database="ok", user="postgres", password="",host="localhost")

df = gpd.GeoDataFrame.from_postgis(sql, con, geom_col='wkb_geometry')

data = pd.read_csv('/home/cryptik/CSV')

dat = data['TOTAL'].tolist()

df['TOTAL'] = data['TOTAL']

fig, ax = plt.subplots(figsize  = (8, 8))

geoplot.choropleth(df, hue='TOTAL', cmap='PuBuGn', figsize=(8, 4),legend='True',ax=ax,scheme='quantiles')

ax.set_axis_off()

plt.title("LPG Consumers")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'LPG Consumers')

# %%
# %matplotlib notebook

import geopandas as gpd
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import geoplot


sql = "select * from gadm36_ind_1"

con = psycopg2.connect(database="ok", user="postgres", password="",host="localhost")

df = gpd.GeoDataFrame.from_postgis(sql, con, geom_col='wkb_geometry')

data = pd.read_csv('/home/cryptik/datafile.csv')

dat = data[' TOTAL'].tolist()

df['TOTAL'] = data[' TOTAL']

fig, ax = plt.subplots(figsize  = (8, 8))

geoplot.choropleth(df, hue='TOTAL', cmap='Blues', figsize=(8, 4),legend='True',ax=ax,scheme='quantiles')

ax.set_axis_off()

plt.title("LPG Outlets")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'LPG Outlets')

# %%
# %matplotlib notebook

import geopandas as gpd
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import geoplot


sql = "select * from gadm36_ind_1"

con = psycopg2.connect(database="ok", user="postgres", password="",host="localhost")

df = gpd.GeoDataFrame.from_postgis(sql, con, geom_col='wkb_geometry')

data = pd.read_csv('/home/cryptik/csv')

dat = data['IOCL/AOD'].tolist()

df['TOTAL'] = data['IOCL/AOD']

fig, ax = plt.subplots(figsize  = (8, 8))

geoplot.choropleth(df, hue='TOTAL', cmap='Reds', figsize=(8, 4),legend='True',ax=ax,scheme='quantiles')

ax.set_axis_off()

plt.title("LPG Consumers of IOCL/AOD")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'LPG Consumers of IOCL/AOD')

# %%
# %matplotlib notebook

import geopandas as gpd
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import geoplot


sql = "select * from gadm36_ind_1"

con = psycopg2.connect(database="ok", user="postgres", password="",host="localhost")

df = gpd.GeoDataFrame.from_postgis(sql, con, geom_col='wkb_geometry')

data = pd.read_csv('/home/cryptik/csv')

dat = data['HPCL'].tolist()

df['TOTAL'] = data['HPCL']

fig, ax = plt.subplots(figsize  = (8, 8))

geoplot.choropleth(df, hue='TOTAL', cmap='PuRd', figsize=(8, 4),legend='True',ax=ax,scheme='quantiles')

ax.set_axis_off()

plt.title("LPG Consumers of HPCL")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'LPG Consumers of HPCL')

# %%
# %matplotlib notebook

import geopandas as gpd
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import geoplot


sql = "select * from gadm36_ind_1"

con = psycopg2.connect(database="ok", user="postgres", password="",host="localhost")

df = gpd.GeoDataFrame.from_postgis(sql, con, geom_col='wkb_geometry')

data = pd.read_csv('/home/cryptik/csv')

dat = data['BPCL'].tolist()

df['TOTAL'] = data['BPCL']

fig, ax = plt.subplots(figsize  = (8, 8))

geoplot.choropleth(df, hue='TOTAL', cmap='YlOrRd', figsize=(8, 4),legend='True',ax=ax,scheme='quantiles')

ax.set_axis_off()

plt.title("LPG Consumers of BPCL")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'LPG Consumers of BPCL')

# %%
# %matplotlib notebook

import geopandas as gpd
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import geoplot


sql = "select * from gadm36_ind_1"

con = psycopg2.connect(database="ok", user="postgres", password="",host="localhost")

df = gpd.GeoDataFrame.from_postgis(sql, con, geom_col='wkb_geometry')

data = pd.read_csv('/home/cryptik/datafile.csv')

dat = data['IOCL/AOD'].tolist()

df['TOTAL'] = data['IOCL/AOD']

fig, ax = plt.subplots(figsize  = (8, 8))

geoplot.choropleth(df, hue='TOTAL', cmap='Paired', figsize=(8, 4),legend='True',ax=ax,scheme='quantiles')

ax.set_axis_off()

plt.title("LPG Outlets of IOCL/AOD")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'LPG Outlets of IOCL/AOD')

# %%
# %matplotlib notebook

import geopandas as gpd
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import geoplot


sql = "select * from gadm36_ind_1"

con = psycopg2.connect(database="ok", user="postgres", password="",host="localhost")

df = gpd.GeoDataFrame.from_postgis(sql, con, geom_col='wkb_geometry')

data = pd.read_csv('/home/cryptik/datafile.csv')

dat = data['BPCL'].tolist()

df['TOTAL'] = data['BPCL']

fig, ax = plt.subplots(figsize  = (8, 8))

geoplot.choropleth(df, hue='TOTAL', cmap='Pastel2', figsize=(8, 4),legend='True',ax=ax,scheme='quantiles')

ax.set_axis_off()

plt.title("LPG Outlets of BPCL")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'LPG Outlets of BPCL')

# %%
# %matplotlib notebook

import geopandas as gpd
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import geoplot


sql = "select * from gadm36_ind_1"

con = psycopg2.connect(database="ok", user="postgres", password="",host="localhost")

df = gpd.GeoDataFrame.from_postgis(sql, con, geom_col='wkb_geometry')

data = pd.read_csv('/home/cryptik/datafile.csv')

dat = data['HPCL'].tolist()

df['TOTAL'] = data['HPCL']

fig, ax = plt.subplots(figsize  = (8, 8))

geoplot.choropleth(df, hue='TOTAL', cmap='Pastel1', figsize=(8, 4),legend='True',ax=ax,scheme='quantiles')

ax.set_axis_off()

plt.title("LPG Outlets of HPCL")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5,1,'LPG Outlets of HPCL')
